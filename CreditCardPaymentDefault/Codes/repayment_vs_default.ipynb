# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# import seaborn as sns

# %%
# Read data
data = pd.read_csv('default.csv')

# %%
data.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_9  PAY_8  PAY_7  PAY_6  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5   ...     BILL_AMOUNT6  BILL_AMOUNT5  BILL_AMOUNT4  PAY_AMOUNT9  \
# 0     -2   ...                0             0             0            0
# 1      0   ...             3272          3455          3261            0
# 2      0   ...            14331         14948         15549         1518
# 3      0   ...            28314         28959         29547         2000
# 4      0   ...            20940         19146         19131         2000
#
#    PAY_AMOUNT8  PAY_AMOUNT7  PAY_AMOUNT6  PAY_AMOUNT5  PAY_AMOUNT4  DEFAULT
# ...

# %%
# Divide repayment status into -2, -1, 0, 1, 2, >=2
data['Sept'] = data['PAY_9'].apply(lambda x:  \
                                                 'delay more than 2 months' if x>2 \
                                                else ('delay 2 months' if x==2 \
                                                     else ('delay 1 month' if x==1 else ('repay duly' if x==-1 \
                                                          else ('use revolving credit' if x==0 else 'no consumption')))))

# %%
# Divide repayment status into -2, -1, 0, 1, 2, >=2
data['Aug'] = data['PAY_8'].apply(lambda x:  \
                                                 'delay more than 2 months' if x>2 \
                                                else ('delay 2 months' if x==2 \
                                                     else ('delay 1 month' if x==1 else ('repay duly' if x==-1 \
                                                          else ('use revolving credit' if x==0 else 'no consumption')))))

# %%
# Divide repayment status into -2, -1, 0, 1, 2, >=2
data['July'] = data['PAY_7'].apply(lambda x:  \
                                                 'delay more than 2 months' if x>2 \
                                                else ('delay 2 months' if x==2 \
                                                     else ('delay 1 month' if x==1 else ('repay duly' if x==-1 \
                                                          else ('use revolving credit' if x==0 else 'no consumption')))))

# %%
# Divide repayment status into -2, -1, 0, 1, 2, >=2
data['June'] = data['PAY_6'].apply(lambda x:  \
                                                 'delay more than 2 months' if x>2 \
                                                else ('delay 2 months' if x==2 \
                                                     else ('delay 1 month' if x==1 else ('repay duly' if x==-1 \
                                                          else ('use revolving credit' if x==0 else 'no consumption')))))

# %%
# Divide repayment status into -2, -1, 0, 1, 2, >=2
data['May'] = data['PAY_5'].apply(lambda x:  \
                                                 'delay more than 2 months' if x>2 \
                                                else ('delay 2 months' if x==2 \
                                                     else ('delay 1 month' if x==1 else ('repay duly' if x==-1 \
                                                          else ('use revolving credit' if x==0 else 'no consumption')))))

# %%
# Divide repayment status into -2, -1, 0, 1, 2, >=2
data['April'] = data['PAY_4'].apply(lambda x:  \
                                                 'delay more than 2 months' if x>2 \
                                                else ('delay 2 months' if x==2 \
                                                     else ('delay 1 month' if x==1 else ('repay duly' if x==-1 \
                                                          else ('use revolving credit' if x==0 else 'no consumption')))))

# %%
data['April'].value_counts()
# Out:
# use revolving credit        16286
# repay duly                   5740
# no consumption               4895
# delay 2 months               2766
# delay more than 2 months      313
# Name: April, dtype: int64

# %%
data['Sept'].value_counts()
# Out:
# use revolving credit        14737
# repay duly                   5686
# delay 1 month                3688
# no consumption               2759
# delay 2 months               2667
# delay more than 2 months      463
# Name: Sept, dtype: int64

# %%
types = data['Sept'].unique()
types.sort()
size = len(data['Sept'].unique())

# %%
print(types)
# Out:
# ['delay 1 month' 'delay 2 months' 'delay more than 2 months'
#  'no consumption' 'repay duly' 'use revolving credit']

# %%
print(size)
# Out:
# 6

# %%
data_yes = data[data['DEFAULT'] == 1]
print(len(data_yes))
# Default which is 1
data_no = data[data['DEFAULT'] == 0]
print(len(data_no))
# Out:
# 6636
# 23364

# %%
data_yes['Sept'].value_counts()
# Out:
# use revolving credit        1888
# delay 2 months              1844
# delay 1 month               1252
# repay duly                   954
# no consumption               365
# delay more than 2 months     333
# Name: Sept, dtype: int64

# %%
data_yes['Aug'].value_counts()
# Out:
# use revolving credit        2503
# delay 2 months              2184
# repay duly                   966
# no consumption               691
# delay more than 2 months     287
# delay 1 month                  5
# Name: Aug, dtype: int64

# %%
print(types)
# Out:
# ['delay 1 month' 'delay 2 months' 'delay more than 2 months'
#  'no consumption' 'repay duly' 'use revolving credit']

# %%
print(types)
# Out:
# ['delay 1 month' 'delay 2 months' 'delay more than 2 months'
#  'no consumption' 'repay duly' 'use revolving credit']

# %%
# Sept
height_yes9 = []
for i in types:
    num_yes = len(data_yes[data_yes['Sept'] == i])
    height_yes9.append(num_yes)
    
height_no9 = []
for i in types:
    num_no = len(data_no[data_no['Sept'] == i])
    height_no9.append(num_no)

# %%
print(height_yes9)
# Out:
# [1252, 1844, 333, 365, 954, 1888]

# %%
print(height_no9)
# Out:
# [2436, 823, 130, 2394, 4732, 12849]

# %%
data['DEFAULT'].value_counts()
# Out:
# 0    23364
# 1     6636
# Name: DEFAULT, dtype: int64

# %%
# Aug
height_yes8 = []
for i in types:
    num_yes = len(data_yes[data_yes['Aug'] == i])
    height_yes8.append(num_yes)
    
height_no8 = []
for i in types:
    num_no = len(data_no[data_no['Aug'] == i])
    height_no8.append(num_no)

# %%
print(height_no8)
# Out:
# [23, 1743, 196, 3091, 5084, 13227]

# %%
# July
height_yes7 = []
for i in types:
    num_yes = len(data_yes[data_yes['July'] == i])
    height_yes7.append(num_yes)
    
height_no7 = []
for i in types:
    num_no = len(data_no[data_no['July'] == i])
    height_no7.append(num_no)

# %%
# June
height_yes6 = []
for i in types:
    num_yes = len(data_yes[data_yes['June'] == i])
    height_yes6.append(num_yes)
    
height_no6 = []
for i in types:
    num_no = len(data_no[data_no['June'] == i])
    height_no6.append(num_no)

# %%
# May
height_yes5 = []
for i in types:
    num_yes = len(data_yes[data_yes['May'] == i])
    height_yes5.append(num_yes)
    
height_no5 = []
for i in types:
    num_no = len(data_no[data_no['May'] == i])
    height_no5.append(num_no)

# %%
# April
height_yes4 = []
for i in types:
    num_yes = len(data_yes[data_yes['April'] == i])
    height_yes4.append(num_yes)
    
height_no4 = []
for i in types:
    num_no = len(data_no[data_no['April'] == i])
    height_no4.append(num_no)

# %%
rate9 = []
for i in range(6):
    r = height_yes9[i] / (height_yes9[i] + height_no9[i])
    rate9.append(r)

# %%
print(rate9)
# Out:
# [0.33947939262472887, 0.6914135733033371, 0.7192224622030238, 0.13229430953243929, 0.16778051354203308, 0.12811291307593134]

# %%
rate8 = []
for i in range(6):
    r = height_yes8[i] / (height_yes8[i] + height_no8[i])
    rate8.append(r)

# %%
print(rate8)
# Out:
# [0.17857142857142858, 0.5561497326203209, 0.5942028985507246, 0.18270756213643574, 0.1596694214876033, 0.15912269548633184]

# %%
rate7 = []
for i in range(6):
    r = height_yes7[i] / (height_yes7[i] + height_no7[i])
    rate7.append(r)

# %%
rate6 = []
for i in range(6):
    r = height_yes6[i] / (height_yes6[i] + height_no6[i])
    rate6.append(r)

# %%
print(height_yes5)
print(height_no5)
# Out:
# [0, 1423, 226, 895, 897, 3195]
# [0, 1203, 116, 3651, 4642, 13752]

# %%
rate5 = []
for i in range(6):
    if height_yes5[i] + height_no5[i] != 0:
        r = height_yes5[i] / (height_yes5[i] + height_no5[i])
    else:
        r = 0        
    rate5.append(r)

# %%
print(rate5)
# Out:
# [0, 0.5418888042650419, 0.6608187134502924, 0.1968763748350198, 0.1619425889149666, 0.18852894317578334]

# %%
rate4 = []
for i in range(6):
    if height_yes4[i] + height_no4[i] != 0:
        r = height_yes4[i] / (height_yes4[i] + height_no4[i])
    else:
        r = 0   
    #r = height_yes4[i] / (height_yes4[i] + height_no4[i])
    rate4.append(r)

# %%
print(rate4)
# Out:
# [0, 0.5065075921908894, 0.670926517571885, 0.2004085801838611, 0.16986062717770034, 0.18844406238487044]

# %%
data[data['DEFAULT'] == 0]['Sept'].value_counts()
# Out:
# use revolving credit        12849
# repay duly                   4732
# delay 1 month                2436
# no consumption               2394
# delay 2 months                823
# delay more than 2 months      130
# Name: Sept, dtype: int64

# %%
all_ = []
all_.append(rate9)
all_.append(rate8)
all_.append(rate7)
all_.append(rate6)
all_.append(rate5)
all_.append(rate4)

# %%
print(all_)
# Out:
# [[0.33947939262472887, 0.6914135733033371, 0.7192224622030238, 0.13229430953243929, 0.16778051354203308, 0.12811291307593134], [0.17857142857142858, 0.5561497326203209, 0.5942028985507246, 0.18270756213643574, 0.1596694214876033, 0.15912269548633184], [0.25, 0.515579994763027, 0.5948717948717949, 0.18531211750305998, 0.1559447625463119, 0.17451154529307283], [0.5, 0.5232668566001899, 0.6446991404011462, 0.1925022999080037, 0.1589590293652189, 0.1832877544819204], [0, 0.5418888042650419, 0.6608187134502924, 0.1968763748350198, 0.1619425889149666, 0.18852894317578334], [0, 0.5065075921908894, 0.670926517571885, 0.2004085801838611, 0.16986062717770034, 0.18844406238487044]]

# %%
rate_all = []
for i in range(6):
    temp = []
    for j in all_:
        temp.append(j[i])
    rate_all.append(temp)

# %%
print(rate_all)
# Out:
# [[0.33947939262472887, 0.17857142857142858, 0.25, 0.5, 0, 0], [0.6914135733033371, 0.5561497326203209, 0.515579994763027, 0.5232668566001899, 0.5418888042650419, 0.5065075921908894], [0.7192224622030238, 0.5942028985507246, 0.5948717948717949, 0.6446991404011462, 0.6608187134502924, 0.670926517571885], [0.13229430953243929, 0.18270756213643574, 0.18531211750305998, 0.1925022999080037, 0.1968763748350198, 0.2004085801838611], [0.16778051354203308, 0.1596694214876033, 0.1559447625463119, 0.1589590293652189, 0.1619425889149666, 0.16986062717770034], [0.12811291307593134, 0.15912269548633184, 0.17451154529307283, 0.1832877544819204, 0.18852894317578334, 0.18844406238487044]]

# %%
x = range(6)
print(x)
# Out:
# range(0, 6)

# %%
x = range(len(types))

# %%
print(x)
# Out:
# range(0, 6)

# %%
# 一个基本的折线图
plt.style.use('ggplot')
plt.figure(figsize=(10,6))
x = range(len(types))
x1 = range(4)
# 收盘价的折线图
plt.plot(x,rate_all[2], '-',label = 'repay delay more than 2 months', marker = 'v', alpha = 0.7, linewidth = 1)
plt.plot(x,rate_all[1], '-',label = 'repay delay 2 months', linewidth = 1, marker = '+')
plt.plot(x1,rate_all[0][:4],':', label = 'repay delay 1 month', linewidth = 2, marker = '>')
plt.plot(x,rate_all[3], '-.',label = 'no consumption', linewidth = 2, marker = 's')
plt.plot(x,rate_all[4], '-.',label = 'repay duly', linewidth = 2, marker = 'o')
plt.plot(x,rate_all[5], '-.',label = 'use revolving credit', linewidth = 2, marker = 'd')

plt.title("The Probability of Default for Different Repayment Groups", size = 16)
plt.xlabel("Time")
# plt.xticks(x,[i for i in data.index])
plt.ylabel("% of Default")
x_desc = ['Sept', 'August','July','June','May','April']
plt.xticks(x, x_desc)
# plt.plot_date(x_date,data['close'],'-',label="收盘价")
# plt.plot_date(x_date,data['high'],'-',color='r',label="开盘价")
plt.legend()
plt.savefig("repay_history.jpg")
plt.grid(True)

# %%
dist = []
for i in types:
    num = len(data[data['Sept'] == i]) + len(data[data['Aug'] == i]) +len(data[data['July'] == i])\
        + len(data[data['June'] == i]) + len(data[data['May'] == i]) + len(data[data['April'] == i]) 
    
    dist.append(num)

# %%
print(dist)
# Out:
# [3722, 18964, 2340, 24415, 34640, 95919]

# %%
# create list to store reprayment types
# prepare data
# Sept


# Aug
height_yes8 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_8'] == i])
    height_yes8.append(num_yes)

height_no8 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_8'] == i])
    height_no8.append(num_no)
    
# July
height_yes7 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_7'] == i])
    height_yes7.append(num_yes)

height_no7 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_7'] == i])
    height_no7.append(num_no)

# June
height_yes6 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_6'] == i])
    height_yes6.append(num_yes)

height_no6 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_6'] == i])
    height_no6.append(num_no)

# May
height_yes5 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_5'] == i])
    height_yes5.append(num_yes)
height_no5 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_5'] == i])
    height_no5.append(num_no)
    
# April
height_yes4 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_4'] == i])
    height_yes4.append(num_yes)
height_no4 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_4'] == i])
    height_no4.append(num_no)
# Out:
# 23364
# 6636

# %%
data['PAY_7'].value_counts()
# Out:
#  0    15764
# -1     5938
# -2     4085
#  2     3819
#  3      240
#  4       76
#  7       27
#  6       23
#  5       21
#  1        4
#  8        3
# Name: PAY_7, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
print(repay_type)
print(size)
# Out:
# [-2 -1  0  1  2  3  4  5  6  7  8]
# 11

# %%
print(len(data))
# Out:
# 30000

# %%
# 9

# %%
repay_type = data['PAY_9'].unique()
repay_type.sort()

height_yes = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_9'] == i])
    height_yes.append(num_yes)

# %%
print(height_yes)
# Out:
# [2394, 4732, 12849, 2436, 823, 78, 24, 13, 5, 2, 8]

# %%
height_no = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_9'] == i])
    height_no.append(num_no)

# %%
print(height_no)
# Out:
# [365, 954, 1888, 1252, 1844, 244, 52, 13, 6, 7, 11]

# %%
# 8
height_yes8 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_8'] == i])
    height_yes8.append(num_yes)

height_no8 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_8'] == i])
    height_no8.append(num_no)

print(height_yes8)
print(height_no8)
# Out:
# [3091, 5084, 13227, 23, 1743, 125, 49, 10, 3, 8, 1]
# [691, 966, 2503, 5, 2184, 201, 50, 15, 9, 12, 0]

# %%
# 7
height_yes7 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_7'] == i])
    height_yes7.append(num_yes)

height_no7 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_7'] == i])
    height_no7.append(num_no)

print(height_yes7)
print(height_no7)
# Out:
# [3328, 5012, 13013, 3, 1850, 102, 32, 9, 9, 5, 1]
# [757, 926, 2751, 1, 1969, 138, 44, 12, 14, 22, 2]

# %%
# 6
height_yes6 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_6'] == i])
    height_yes6.append(num_yes)

height_no6 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_6'] == i])
    height_no6.append(num_no)

print(height_yes6)
print(height_no6)
# Out:
# [3511, 4783, 13439, 1, 1506, 70, 23, 17, 3, 10, 1]
# [837, 904, 3016, 1, 1653, 110, 46, 18, 2, 48, 1]

# %%
# 5
height_yes5 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_5'] == i])
    height_yes5.append(num_yes)

height_no5 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_5'] == i])
    height_no5.append(num_no)

print(height_yes5)
print(height_no5)
# Out:
# [3651, 4642, 13752, 0, 1203, 65, 33, 7, 1, 10, 0]
# [895, 897, 3195, 0, 1423, 113, 51, 10, 3, 48, 1]

# %%
# 4
height_yes4 = []
for i in repay_type:
    num_yes = len(data_yes[data_yes['PAY_4'] == i])
    height_yes4.append(num_yes)

height_no4 = []
for i in repay_type:
    num_no = len(data_no[data_no['PAY_4'] == i])
    height_no4.append(num_no)

print(height_yes4)
print(height_no4)
# Out:
# [3914, 4765, 13217, 0, 1365, 66, 18, 6, 5, 8, 0]
# [981, 975, 3069, 0, 1401, 118, 31, 7, 14, 38, 2]

# %%
plt.figure()
plt.figure(figsize=(20,16))

# 绘制第一个图

plt.subplot(2, 3, 1)

total_width, n = 0.8, 2
width = total_width / n

x = range(11)
ratio = []
radius = []
for i in range(len(height_yes)):
    ratio.append(height_no[i]/(height_no[i]+height_yes[i]))
    radius.append((height_no[i]+height_yes[i])/20)
plt.scatter(x, ratio, s=radius, label='non-default')

x_desc = ['pre-statement', 'duly','delay < 1 ','delay 1','delay 2','delay 3','delay 4','delay 5','delay 6','delay 7','delay 8']
plt.xticks(x, x_desc, rotation=90)


my_y_ticks = np.arange(0, 1, 0.1)
plt.yticks(my_y_ticks)

plt.xlabel('Repayment Status')
plt.ylabel('Number of Clients')
plt.title('September')


plt.subplot(2, 3, 2)
total_width, n = 0.8, 2
width = total_width / n

ratio = []
radius = []
for i in range(len(height_yes8)):
    ratio.append(height_no8[i]/(height_no8[i]+height_yes8[i]))
    radius.append((height_no8[i]+height_yes8[i])/20)
plt.scatter(x, ratio, s=radius, label='non-default')

x_desc = ['pre-statement', 'duly','delay < 1 ','delay 1','delay 2','delay 3','delay 4','delay 5','delay 6','delay 7','delay 8']
plt.xticks(x, x_desc, rotation=90)
my_y_ticks = np.arange(0, 1, 0.1)
plt.yticks(my_y_ticks)

plt.xlabel('Repayment Status')
plt.ylabel('Number of Clients')
plt.title('August')
plt.legend()

plt.subplot(2, 3, 3)
total_width, n = 0.8, 2
width = total_width / n

ratio = []
radius = []
for i in range(len(height_yes7)):
    ratio.append(height_no7[i]/(height_no7[i]+height_yes7[i]))
    radius.append((height_no7[i]+height_yes7[i])/20)
plt.scatter(x, ratio, s=radius, label='non-default')

x_desc = ['pre-statement', 'duly','delay < 1 ','delay 1','delay 2','delay 3','delay 4','delay 5','delay 6','delay 7','delay 8']
plt.xticks(x, x_desc, rotation=90)
my_y_ticks = np.arange(0, 1, 0.1)
plt.yticks(my_y_ticks)

plt.xlabel('Repayment Status')
plt.ylabel('Number of Clients')
plt.title('July')
plt.legend()

plt.subplot(2, 3, 4)
total_width, n = 0.8, 2
width = total_width / n

ratio = []
radius = []
for i in range(len(height_yes6)):
    ratio.append(height_no6[i]/(height_no6[i]+height_yes6[i]))
    radius.append((height_no6[i]+height_yes6[i])/20)
plt.scatter(x, ratio, s=radius, label='non-default')

x_desc = ['pre-statement', 'duly','delay < 1 ','delay 1','delay 2','delay 3','delay 4','delay 5','delay 6','delay 7','delay 8']
plt.xticks(x, x_desc, rotation=90)
my_y_ticks = np.arange(0, 1, 0.1)
plt.yticks(my_y_ticks)

plt.xlabel('Repayment Status')
plt.ylabel('Number of Clients')
plt.title('June')
plt.legend()

plt.subplot(2, 3, 5)
total_width, n = 0.8, 2
width = total_width / n

ratio = []
radius = []
for i in range(len(height_yes5)):
    ratio.append(height_no5[i]/(height_no5[i]+height_yes5[i]+1))
    radius.append((height_no5[i]+height_yes5[i])/20)
plt.scatter(x, ratio, s=radius, label='non-default')

x_desc = ['pre-statement', 'duly','delay < 1 ','delay 1','delay 2','delay 3','delay 4','delay 5','delay 6','delay 7','delay 8']
plt.xticks(x, x_desc, rotation=90)
my_y_ticks = np.arange(0, 1, 0.1)
plt.yticks(my_y_ticks)

plt.xlabel('Repayment Status')
plt.ylabel('Number of Clients')
plt.title('May')
plt.legend()

plt.subplot(2, 3, 6)
total_width, n = 0.8, 2
width = total_width / n

ratio = []
radius = []
for i in range(len(height_yes4)):
    ratio.append(1000*(height_no4[i]/(height_no4[i]+height_yes4[i]+1))**2)
    radius.append((height_no4[i]+height_yes4[i]))
plt.scatter(x, radius, s=ratio, label='non-default')

x_desc = ['pre-statement', 'duly','delay < 1 ','delay 1','delay 2','delay 3','delay 4','delay 5','delay 6','delay 7','delay 8']
plt.xticks(x, x_desc, rotation=90)
my_y_ticks = np.arange(0, 1, 0.1)
#plt.yticks(my_y_ticks)

plt.xlabel('Repayment Status')
plt.ylabel('Number of Clients')
plt.title('April')
plt.legend()

font1 = {'family': 'Times New Roman',
'weight': 'normal',
'size': 16,
}

plt.suptitle('Repayment History (May-September) V.S. Default Results (October)',fontsize=16)
plt.savefig("1.jpg")
plt.show()

# %%
pal = dict(1="seagreen", 0="gray")
g = sns.FacetGrid(data, hue="DEFAULT", palette=pal, height=5)
g.map(plt.scatter, "LIMIT_BAL", "AGE", s=50, alpha=.7, linewidth=.5, edgecolor="white")
g.add_legend();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-159-73e959603f2d> in <module>()
#       1 #pal = dict(1="seagreen", 0="gray")
# ----> 2 g = sns.FacetGrid(data, hue="DEFAULT", palette=pal, height=5)
#       3 g.map(plt.scatter, "LIMIT_BAL", "AGE", s=50, alpha=.7, linewidth=.5, edgecolor="white")
#       4 g.add_legend();
#
# NameError: name 'pal' is not defined

# %%
data['LIMIT_BAL'].value_counts().max()
data['LIMIT_BAL'].value_counts().min()
data['LIMIT_BAL'].value_counts()
# Out:
# 50000      3365
# 20000      1976
# 30000      1610
# 80000      1567
# 200000     1528
# 150000     1110
# 100000     1048
# 180000      995
# 360000      881
# 60000       825
# 140000      749
# 230000      737
# 70000       731
# 210000      730
# 130000      729
# 120000      726
# 500000      722
# 160000      694
# 90000       651
# 240000      619
# 110000      588
# 300000      554
# 170000      532
# 260000      521
# 280000      493
# 10000       493
# 220000      469
# 250000      350
# 290000      348
# 320000      312
#            ...
# 520000       20
# 510000       19
# 600000       16
# 580000       11
# 610000       11
# 530000       10
# 560000       10
# 620000        9
# 700000        8
# 570000        8
# 630000        7
# 640000        7
# 540000        6
# 590000        6
# 710000        6
# 680000        4
# 750000        4
# 650000        3
# 670000        3
# 720000        3
# 660000        3
# 16000         2
# 780000        2
# 740000        2
# ...

# %%
g = sns.FacetGrid(data, col="DEFAULT", margin_titles=True, height=4)
g.map(plt.scatter, "AGE", "LIMIT_BAL", color="#338844", edgecolor="white", s=50, lw=1)
for ax in g.axes.flat:
    ax.plot((0, 50), (0, .2 * 50), c=".2", ls="--")
g.set(xlim=(0, 60), ylim=(0, 75000));

# %%
# plot first graph: analysis cqc correlation scatter 0802
#####
plt.figure(figsize=(10,6))
colors = ['b','g','r','orange']
# colors = ['cornflowerblue', 'seagreen', 'orange', 'm']
# labels = cor2['EXPERIENCE_TYPE'].unique().tolist()
labels = ['1 year and below', '1-5 years', '5-10 years','over 10 years']


plt.scatter(data_no['AGE'], data_no['LIMIT_BAL'], alpha=0.8, cmap='brg', s=60, linewidths = '1',edgecolor='0', marker='8')
plt.show()

# %%
# plot first graph: analysis cqc correlation scatter 0802
#####
plt.figure(figsize=(10,6))
colors = ['b','g','r','orange']
# colors = ['cornflowerblue', 'seagreen', 'orange', 'm']
# labels = cor2['EXPERIENCE_TYPE'].unique().tolist()
labels = ['1 year and below', '1-5 years', '5-10 years','over 10 years']

for i in range(len(cor2['EXPERIENCE_TYPE'].unique())):
    cqc = cor2[cor2['EXPERIENCE_TYPE'] == labels[i]]['FINAL_CQC'].tolist()
    exp = cor2[cor2['EXPERIENCE_TYPE'] == labels[i]]['TIME_INTERVAL_MON'].tolist()
    plt.scatter(exp, cqc, c=colors[i], alpha=0.8, cmap='brg', s=60, linewidths = '1',edgecolor='0', marker='8', label = labels[i])

# ---------------------------------------
# plt.legend()

# %%
# f, ax = plt.subplots(figsize = (14, 10))
with sns.axes_style(style='ticks'):
    g = sns.factorplot("EDUCATION", "LIMIT_BAL", "DEFAULT", data=data, kind="box")
    g.set_axis_labels("Education", "Amount of Given Credit");

    
legend = ax.legend(['Y','N'])  
# legend.texts[0].set_text("Whatever else") 
print(legend)
# Out:
# /anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-189-03f4041f76b4> in <module>()
#       5
#       6
# ----> 7     legend = g.legend(['Y','N'])
#       8 # legend.texts[0].set_text("Whatever else")
#       9 print(legend)
#
# AttributeError: 'FacetGrid' object has no attribute 'legend'

# %%
fig, ax =plt.subplots(2,3)
# sns.countplot(df['batting'], ax=ax[0])
# sns.countplot(df['bowling'], ax=ax[1])

sns.catplot(x="PAY_9", hue="DEFAULT", kind="count",
            palette="pastel", edgecolor=".6",
            data=data, ax=ax[0,0]);

sns.catplot(x="PAY_8", hue="DEFAULT", kind="count",
            palette="pastel", edgecolor=".6",
            data=data, ax=ax[0,1]);

sns.catplot(x="PAY_7", hue="DEFAULT", kind="count",
            palette="pastel", edgecolor=".6",
            data=data, ax=ax[0,2]);

sns.catplot(x="PAY_6", hue="DEFAULT", kind="count",
            palette="pastel", edgecolor=".6",
            data=data, ax=ax[1,0]);

sns.catplot(x="PAY_5", hue="DEFAULT", kind="count",
            palette="pastel", edgecolor=".6",
            data=data, ax=ax[1,1]);

sns.catplot(x="PAY_4", hue="DEFAULT", kind="count",
            palette="pastel", edgecolor=".6",
            data=data, ax=ax[1,2]);

fig.show()


# fig, ax =plt.subplots(1,2)
# sns.countplot(df['batting'], ax=ax[0])
# sns.countplot(df['bowling'], ax=ax[1])
# fig.show()
# Out:
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
# pyplot
plt.figure(figsize=(10, 5))
total_width, n = 0.8, 2
width = total_width / n
x = x - (total_width - width)

plt.bar(x, height_yes,  width=width, label='non-default')
plt.bar(x + width, height_no, width=width, label='default')

x_desc = []
plt.legend()
plt.show()

# %%
print(len(data[data['PAY_9'] == 2]))
# Out:
# 2667

# %%
d = data[data['PAY_9'] == 2]

# %%
n = d[d['DEFAULT'] == 1]

# %%
print(len(n))
# Out:
# 1844
